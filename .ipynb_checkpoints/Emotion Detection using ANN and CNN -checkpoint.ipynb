# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from glob import glob
import warnings
import tensorflow as tf
import seaborn as sb
import librosa
import IPython.display as ipd
import librosa.display
import json
import math
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from keras import models, layers, optimizers
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Testing an audio file to check if it is working fine while loading

# %%
path = os.getcwd()
file = "Solely Urdu Dataset/Angry"
new = os.path.join(path, file)
os.chdir(new)

# %%
ipd.Audio(os.listdir()[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Plotting a waveplot of an audio to understand how amplitude varies with time

# %%
y, sr = librosa.load(os.listdir()[0], duration=3.00)
mfccs = librosa.feature.mfcc(y, sr=sr, n_mfcc=13)
delta_mfccs = librosa.feature.delta(mfccs)
delta_delta_mfccs = librosa.feature.delta(mfccs, order=2)
comprehensive_mfccs = np.concatenate((mfccs, delta_mfccs, delta_delta_mfccs))
print(comprehensive_mfccs.shape)
print(librosa.display.waveplot(comprehensive_mfccs, sr=sr))

# %%
ps = librosa.feature.melspectrogram(y=y, sr=sr)
print(librosa.display.waveplot(ps, sr=sr))

# %%
spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000) 
spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(spectrogram, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Angry')
plt.savefig('MelSpec_MaleNeutral.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# ### Creating Mel Frequency Cepstral Coefficients dataset for each voice sample in a JSON file

# %%
DATASET_PATH = "D:/Solely Urdu Dataset/"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 1
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=3):
    """Extracts MFCCs from Urdu voice dataset and saves them into a json file along witgh emotion labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all voice sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a voice sub-folder level
        if dirpath is not dataset_path:

            # save voice label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in voice sub-dir
            for f in filenames:

            # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish],
                                                sample_rate, 
                                                n_mfcc=num_mfcc, 
                                                n_fft=n_fft, 
                                                hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))


    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        

save_mfcc(DATASET_PATH, JSON_PATH, num_segments=3)

# %% [markdown]
# ### Loading Data

# %%
DATA_PATH = "D:/Urdu_Voice/data.json"

def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    x = np.array(data["mfcc"])
    y = np.array(data["labels"])
    
    print("Data succesfully loaded!")

    return  x, y

x, y = load_data(DATA_PATH)
# Out:
# Data succesfully loaded!

# %%
x[0]
# Out:
# array([[-2.79308901e+02,  1.30601654e+02,  1.99235175e+01,
#          3.29198380e+01,  3.39893405e+01, -2.12859030e+01,
#         -1.93898060e+01, -1.38480511e+01, -1.71849149e+01,
#          5.04127106e+00, -1.09404035e+00,  4.56557660e+00,
#         -4.60111083e+00],
#        [-2.91764588e+02,  1.44363627e+02,  1.88892418e+01,
#          3.29803044e+01,  2.78476923e+01, -1.23181006e+01,
#         -1.30559052e+01, -1.24785895e+01, -1.49228688e+01,
#          1.31779925e+00, -4.49978725e+00,  4.96078635e+00,
#         -3.62683251e+00],
#        [-3.15968862e+02,  1.40716744e+02,  1.41420670e+01,
#          3.43953234e+01,  1.44346620e+01, -2.94479228e+00,
#         -2.08023068e+00, -7.44297867e+00, -1.06823937e+01,
#          6.28622713e-01, -9.46858825e+00,  7.01815724e+00,
#          2.44991799e+00],
#        [-2.71015872e+02,  8.13141692e+01,  1.63216568e+01,
#          4.11204742e+01, -1.35956318e+00,  8.10630417e-02,
#         -3.24095306e+00, -9.28310288e+00, -7.87743709e+00,
#          1.35996533e+01, -1.17017785e+01,  1.39790380e+01,
#          3.81387597e-01],
#        [-2.07225047e+02,  3.50543963e+01,  3.87994103e+00,
#          4.19665786e+01, -1.72727285e+01, -5.87392935e-02,
#          4.44230639e-01,  4.73417297e-01, -2.24998109e+01,
#          2.30183428e+01, -6.77659711e+00,  5.56978903e+00,
#          3.90834129e+00],
#        [-1.21985271e+02,  1.54613379e+01,  8.10876236e+00,
#          4.07752579e+01, -2.38908169e+01, -1.12300476e+00,
#          1.61662999e+00,  8.39772139e+00, -2.58823665e+01,
#          1.73011056e+01, -9.33674733e+00,  2.86028775e+00,
#          3.66228133e+00],
#        [-8.48952523e+01,  3.55830958e+01,  1.70971620e+01,
#          5.16141993e+01, -6.84115169e+00, -2.58044259e+00,
#         -1.43527368e+01,  4.31810154e+00, -2.87668351e+01,
#         -3.18613602e-01, -2.25361883e+01,  8.71516668e-01,
#         -2.51572491e+00],
#        [-9.53809349e+01,  7.82663636e+01, -6.05271007e+00,
#          5.61114568e+01,  1.16674375e+01, -8.62663162e+00,
#         -3.13707008e+01, -5.58148174e+00, -2.85599511e+01,
#          2.86664908e+00, -2.24746297e+01,  9.06769281e+00,
#          3.22646728e+00],
#        [-1.49731632e+02,  1.22101182e+02, -3.10382493e+01,
#          4.97434854e+01,  1.53149644e+01, -2.52190649e+01,
#         -3.12052351e+01, -1.10262603e+01, -3.16470185e+01,
#          2.38239518e+01, -2.67667616e+01,  1.43013427e+01,
#          7.72043099e+00],
#        [-2.03672922e+02,  1.24987355e+02, -2.43002489e+01,
#          3.83730417e+01,  2.19625539e+01, -2.11188325e+01,
#         -3.07986935e+01, -7.89595958e+00, -2.77119915e+01,
#          1.97379181e+01, -2.71679476e+01, -1.55073884e-01,
#          9.56900485e+00],
#        [-1.77226568e+02,  8.97612296e+01, -2.11435386e+01,
#          3.65320662e+01,  2.76694951e+01, -2.67542158e+01,
#         -2.91230615e+01,  7.54589628e+00, -2.61609650e+01,
#          1.09693540e+01, -2.92574444e+01,  2.08440605e+00,
#          5.71476831e+00],
#        [-1.73089181e+02,  6.84366901e+01, -1.63468544e+01,
#          3.91070160e+01,  1.96148996e+01, -3.12500346e+01,
#         -2.58368438e+01,  1.07885723e+01, -2.74165138e+01,
#          4.11681246e+00, -3.26136565e+01,  1.16588178e+01,
#         -3.48158879e+00],
#        [-1.69693537e+02,  6.25145557e+01, -8.30466034e+00,
#          4.16017490e+01,  1.02096694e+01, -2.96978295e+01,
#         -2.10002052e+01,  8.97166659e+00, -2.69012416e+01,
#          5.23800851e+00, -3.24520147e+01,  1.74278152e+01,
#         -4.08508030e+00],
#        [-1.18008987e+02,  8.16686602e+01, -1.37182830e+01,
#          2.55863356e+01, -3.11532387e-01, -3.74668110e+01,
#         -2.58145578e+01,  5.40375077e+00, -2.11711677e+01,
#          1.15367111e+01, -2.59591361e+01,  2.06665490e+01,
#         -2.45999043e+00],
#        [-9.90020928e+01,  1.12273984e+02, -1.30142805e+01,
#          1.91748622e+01, -7.49474380e+00, -3.93555957e+01,
#         -2.92059083e+01, -6.82405628e+00, -1.87762712e+01,
#          2.31531922e+01, -2.30838184e+01,  1.91447876e+01,
#          4.43419971e+00]])

# %%
x.shape, y.shape
# Out:
# ((1197, 15, 13), (1197,))

# %% [markdown]
# ### Artificial Neural Networtk (ANN) model building

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(x.shape[1], x.shape[2])),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(4, activation='softmax')
])

optimiser = keras.optimizers.Adam()
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 195)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               100352
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 248,388
# Trainable params: 248,388
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=16, epochs=100, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/100
# 45/45 [==============================] - 1s 7ms/step - loss: 7.9938 - accuracy: 0.5635 - val_loss: 2.1969 - val_accuracy: 0.7333
# Epoch 2/100
# 45/45 [==============================] - 0s 4ms/step - loss: 2.2227 - accuracy: 0.7099 - val_loss: 3.6840 - val_accuracy: 0.6944
# Epoch 3/100
# 45/45 [==============================] - 0s 4ms/step - loss: 2.1743 - accuracy: 0.7043 - val_loss: 1.2367 - val_accuracy: 0.7500
# Epoch 4/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0
# 45/45 [==============================] - 0s 4ms/step - loss: 5.1305e-05 - accuracy: 1.0000 - val_loss: 0.9112 - val_accuracy: 0.9056
# Epoch 93/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.9609e-05 - accuracy: 1.0000 - val_loss: 0.9145 - val_accuracy: 0.9056
# Epoch 94/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.8874e-05 - accuracy: 1.0000 - val_loss: 0.9164 - val_accuracy: 0.9056
# Epoch 95/100
# 45/45 [==============================] - 0s 3ms/step - loss: 4.8232e-05 - accuracy: 1.0000 - val_loss: 0.9160 - val_accuracy: 0.9056
# Epoch 96/100
# 45/45 [==============================] - 0s 3ms/step - loss: 4.6984e-05 - accuracy: 1.0000 - val_loss: 0.9191 - val_accuracy: 0.9056
# Epoch 97/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.5927e-05 - accuracy: 1.0000 - val_loss: 0.9168 - val_accuracy: 0.9056
# Epoch 98/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.4259e-05 - accuracy: 1.0000 - val_loss: 0.9203 - val_accuracy: 0.9056
# Epoch 99/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.2638e-05 - accuracy: 1.0000 - val_loss: 0.9214 - val_accuracy: 0.9056
# Epoch 100/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.1723e-05 - accuracy: 1.0000 - val_loss: 0.9210 - val_accuracy: 0.9056

# %%
history_dict=history.history
loss_values=history_dict['loss']
acc_values=history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values=history_dict['val_accuracy']
epochs=range(1,101)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss1, test_acc1 = model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9828 - accuracy: 0.8533

# %% [markdown]
# ### Splitting data into validation, training, test

# %%
def prepare_datasets(test_size, validation_size):
    
    X, y = load_data(DATA_PATH)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)
    #X_train = X_train[..., np.newaxis]
    #X_validation = X_validation[..., np.newaxis]
    #X_test = X_test[..., np.newaxis]
    
    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)
# Out:
# Data succesfully loaded!

# %% [markdown]
# ### Changing Data Shape and Adding new axis for Conv2D

# %%
X_train_Conv2D = X_train[..., np.newaxis]
X_validation_Conv2D = X_validation[..., np.newaxis]
X_test_Conv2D = X_test[..., np.newaxis]

# %%
X_train_Conv2D.shape
# Out:
# (717, 15, 13, 1)

# %%
X_train.shape
# Out:
# (717, 15, 13)

# %% [markdown]
# ### Convolutional 2D Neural Network Model

# %%
model_conv2D = keras.Sequential()

model_conv2D.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(X_train.shape[1], X_train.shape[2], 1)))
model_conv2D.add(keras.layers.BatchNormalization())
model_conv2D.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model_conv2D.add(keras.layers.Conv2D(64, (3, 3), activation='relu'))
model_conv2D.add(keras.layers.BatchNormalization())
model_conv2D.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model_conv2D.add(keras.layers.Conv2D(64, (2, 2), activation='relu'))
model_conv2D.add(keras.layers.BatchNormalization())
model_conv2D.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))

model_conv2D.add(keras.layers.Flatten())

# %%
model_conv2d_lstm = keras.Sequential()

model_conv2d_lstm.add(keras.layers.TimeDistributed(model_conv2D, input_shape=(X_train.shape[1], X_train.shape[2], 1, 1)))
model_conv2D_lstm.add(keras.layers.LSTM(32, activation='relu'))

model_conv2D_lstm.add(keras.layers.Dense(64, activation='relu'))
#model_conv2D.add(keras.layers.Dropout(0.3))
model_conv2D_lstm.add(keras.layers.Dense(4, activation='softmax'))
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 15, 13, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 15, 13, 1), dtype=tf.float32, name='conv2d_24_input'), name='conv2d_24_input', description="created by layer 'conv2d_24_input'"), but it was called on an input with incompatible shape (None, 13, 1, 1).
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1879   try:
# -> 1880     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1881   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 3 from 1 for '{{node time_distributed_51/sequential_11/conv2d_24/Conv2D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](time_distributed_51/Reshape, time_distributed_51/sequential_11/conv2d_24/Conv2D/ReadVariableOp)' with input shapes: [?,13,1,1], [3,3,1,32].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/1212282062.py in <module>
#       1 model_conv2d_lstm = keras.Sequential()
#       2
# ----> 3 model_conv2d_lstm.add(keras.layers.TimeDistributed(model_conv2D, input_shape=(X_train.shape[1], X_train.shape[2], 1, 1)))
#       4 model_conv2D_lstm.add(keras.layers.LSTM(32, activation='relu'))
#       5
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     200           # and create the node connecting the current layer
#     201           # to the input layer we just created.
# --> 202           layer(x)
#     203           set_inputs = True
#     204
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     976       return self._functional_construction_call(inputs, args, kwargs,
# --> 977                                                 input_list)
#     978
#     979     # Maintains info about the `Layer.call` stack.
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1113       # Check input assumptions set after layer building, e.g. input shape.
#    1114       outputs = self._keras_tensor_symbolic_call(
# -> 1115           inputs, input_masks, args, kwargs)
#    1116
#    1117       if outputs is None:
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     846       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     847     else:
# --> 848       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     849
#     850   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     886           self._maybe_build(inputs)
#     887           inputs = self._maybe_cast_inputs(inputs)
# --> 888           outputs = call_fn(inputs, *args, **kwargs)
#     889
#     890         self._handle_activity_regularization(inputs, outputs)
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\layers\wrappers.py in call(self, inputs, training, mask)
#     266           kwargs['mask'] = backend.reshape(mask, inner_mask_shape)
#     267
# --> 268         y = self.layer(inputs, **kwargs)
#     269
#     270         # Shape: (num_samples, timesteps, ...)
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\sequential.py in call(self, inputs, training, mask)
#     367       if not self.built:
#     368         self._init_graph_network(self.inputs, self.outputs)
# --> 369       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     370
#     371     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\functional.py in call(self, inputs, training, mask)
#     413     """
#     414     return self._run_internal_graph(
# --> 415         inputs, training=training, mask=mask)
#     416
#     417   def compute_output_shape(self, input_shape):
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\anaconda3\envs\Bilal\lib\site-packages\keras\layers\convolutional.py in call(self, inputs)
#     247       inputs = tf.pad(inputs, self._compute_causal_padding(inputs))
#     248
# --> 249     outputs = self._convolution_op(inputs, self.kernel)
#     250
#     251     if self.use_bias:
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\ops\nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1136       data_format=data_format,
#    1137       dilations=dilations,
# -> 1138       name=name)
#    1139
#    1140
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\ops\nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1266           data_format=data_format,
#    1267           dilations=dilations,
# -> 1268           name=name)
#    1269     else:
#    1270       if channel_index == 1:
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\ops\nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2720         data_format=data_format,
#    2721         dilations=dilations,
# -> 2722         name=name)
#    2723   return squeeze_batch_dims(
#    2724       input,
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     970                   padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
#     971                   explicit_paddings=explicit_paddings,
# --> 972                   data_format=data_format, dilations=dilations, name=name)
#     973   _result = _outputs[:]
#     974   if _execute.must_record_gradient():
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     748       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     749                                  name=scope, input_types=input_types,
# --> 750                                  attrs=attr_protos, op_def=op_def)
#     751
#     752     # `outputs` is returned as a separate return value so that the output
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     599     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     600         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 601         compute_device)
#     602
#     603   def capture(self, tensor, name=None, shape=None):
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3567           input_types=input_types,
#    3568           original_op=self._default_original_op,
# -> 3569           op_def=op_def)
#    3570       self._create_op_helper(ret, compute_device=compute_device)
#    3571     return ret
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2040         op_def = self._graph._get_op_def(node_def.op)
#    2041       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2042                                 control_input_ops, op_def)
#    2043       name = compat.as_str(node_def.name)
#    2044
#
# ~\anaconda3\envs\Bilal\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1881   except errors.InvalidArgumentError as e:
#    1882     # Convert to ValueError for backwards compatibility.
# -> 1883     raise ValueError(str(e))
#    1884
#    1885   return c_op
#
# ValueError: Negative dimension size caused by subtracting 3 from 1 for '{{node time_distributed_51/sequential_11/conv2d_24/Conv2D}} = Conv2D[T=DT_FLOAT, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](time_distributed_51/Reshape, time_distributed_51/sequential_11/conv2d_24/Conv2D/ReadVariableOp)' with input shapes: [?,13,1,1], [3,3,1,32].

# %%
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_conv2D_lstm.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_conv2D.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/757156885.py in <module>
#       1 optimiser = keras.optimizers.Adam(learning_rate=0.0001)
# ----> 2 model_conv2D_lstm.compile(optimizer=optimiser,
#       3               loss='sparse_categorical_crossentropy',
#       4               metrics=['accuracy'])
#       5
#
# NameError: name 'model_conv2D_lstm' is not defined

# %%
history_conv2D = model_conv2D_lstm.fit(X_train_Conv2D, y_train, batch_size=16, epochs=100, validation_data=(X_validation_Conv2D, y_validation))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/2234955324.py in <module>
# ----> 1 history_conv2D = model_conv2D_lstm.fit(X_train_Conv2D, y_train, batch_size=16, epochs=100, validation_data=(X_validation_Conv2D, y_validation))
#
# NameError: name 'model_conv2D_lstm' is not defined

# %%
history_dict = history_conv2D.history
loss_values = history_dict['loss']
acc_values = history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values = history_dict['val_accuracy']
epochs=range(1,101)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss_Conv2D, test_acc_Conv2D = model_conv2D.evaluate(X_test_Conv2D, y_test)
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6813 - accuracy: 0.8033

# %% [markdown]
# ### Convolutional 1D Model

# %%
model_conv1D = keras.Sequential()

# %%
model_conv1D.add(keras.layers.Conv1D(32, 5, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_conv1D.add(keras.layers.MaxPool1D(2, strides=1, padding='same'))

model_conv1D.add(keras.layers.Conv1D(64, 5, activation='relu'))
model_conv1D.add(keras.layers.MaxPool1D(2, strides=1, padding='same'))

model_conv1D.add(keras.layers.Conv1D(64, 5, activation='relu'))
model_conv1D.add(keras.layers.MaxPool1D(2, strides=1, padding='same'))
 
#----------------------------------

#model_conv1D.add(keras.layers.GlobalMaxPooling1D())

model_conv1D.add(keras.layers.LSTM(32, dropout=0.1, recurrent_dropout=0.5))

model_conv1D.add(keras.layers.Dense(64, activation='relu'))
#model_conv1D.add(keras.layers.Dropout(0.3))
model_conv1D.add(keras.layers.Dense(4, activation='softmax'))

optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_conv1D.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_conv1D.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_70 (Conv1D)           (None, 11, 32)            2112
# _________________________________________________________________
# max_pooling1d_53 (MaxPooling (None, 11, 32)            0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 7, 64)             10304
# _________________________________________________________________
# max_pooling1d_54 (MaxPooling (None, 7, 64)             0
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 3, 64)             20544
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, 3, 64)             0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 32)                12416
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_39 (Dense)             (None, 4)                 260
# =================================================================
# Total params: 47,748
# Trainable params: 47,748
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_conv1D = model_conv1D.fit(X_train, y_train, batch_size=16, epochs=200, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/200
# 45/45 [==============================] - 5s 22ms/step - loss: 1.3302 - accuracy: 0.3459 - val_loss: 1.2776 - val_accuracy: 0.4222
# Epoch 2/200
# 45/45 [==============================] - 0s 10ms/step - loss: 1.2674 - accuracy: 0.4519 - val_loss: 1.2209 - val_accuracy: 0.4944
# Epoch 3/200
# 45/45 [==============================] - 0s 10ms/step - loss: 1.2190 - accuracy: 0.5077 - val_loss: 1.1528 - val_accuracy: 0.6222
# Epoch 4/200
# 45/45 [==============================] - 0s 11ms/step - loss: 1.1730 - accuracy: 0.5300 - val_loss: 1.1148 - val_accuracy: 0.6389
# Epoch 5/200
# 45/45 [==============================] - 0s 9ms/step - loss: 1.1331 - accuracy: 0.5858 - val_loss: 1.0926 - val_accuracy: 0.6056
# Epoch 6/200
# 45/45 [==============================] - 0s 11ms/step - loss: 1.0900 - accuracy: 0.5955 - val_loss: 1.0191 - val_accuracy: 0.6667
# Epoch 7/200
# 45/45 [==============================] - 0s 10ms/step - loss: 1.0433 - accuracy: 0.6471 - val_loss: 0.9884 - val_accuracy: 0.6667
# Epoch 8/200
# 45/45 [==============================] - 0s 11ms/step - loss: 0.9769 - accuracy: 0.6695 - val_loss: 0.9323 - val_accuracy: 0.7111
# Epoch 9/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.9305 - accuracy: 0.6834 - val_loss: 0.9148 - val_accuracy: 0.7000
# Epoch 10/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.8779 - accuracy: 0.7099 - val_loss: 0.8173 - val_accuracy: 0.7222
# Epoch 11/200
# 45/45 [==============================] - 0s 11ms/step - loss: 0.8389 - accuracy: 0.7364 - val_loss: 0.7860 - val_accuracy: 0.7611
# Epoch 12/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0
200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.8290 - val_accuracy: 0.8556
# Epoch 185/200
# 45/45 [==============================] - 0s 9ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.8078 - val_accuracy: 0.8667
# Epoch 186/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8085 - val_accuracy: 0.8722
# Epoch 187/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.7802 - val_accuracy: 0.8611
# Epoch 188/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7894 - val_accuracy: 0.8667
# Epoch 189/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.8003 - val_accuracy: 0.8722
# Epoch 190/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.7908 - val_accuracy: 0.8667
# Epoch 191/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7954 - val_accuracy: 0.8722
# Epoch 192/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8393 - val_accuracy: 0.8611
# Epoch 193/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7962 - val_accuracy: 0.8722
# Epoch 194/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8064 - val_accuracy: 0.8667
# Epoch 195/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8073 - val_accuracy: 0.8722
# Epoch 196/200
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8008 - val_accuracy: 0.8611
# Epoch 197/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7956 - val_accuracy: 0.8667
# Epoch 198/200
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.7841 - val_accuracy: 0.8611
# Epoch 199/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7953 - val_accuracy: 0.8667
# Epoch 200/200
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7969 - val_accuracy: 0.8667

# %%
history_dict = history_conv1D.history
loss_values = history_dict['loss']
acc_values = history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values = history_dict['val_accuracy']
epochs=range(1,201)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss_conv1D, test_acc_conv1D = model_conv1D.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6408 - accuracy: 0.8667

# %%
X_train.shape, X_test.shape, X_validation.shape
# Out:
# ((717, 15, 13), (300, 15, 13), (180, 15, 13))

# %% [markdown]
# ### LSTM Model

# %%
model_lstm = keras.models.Sequential()

# %%
model_lstm.add(keras.layers.Bidirectional(layers.LSTM(32), input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm.add(keras.layers.Dense(64, activation='relu'))
#model_lstm.add(keras.layers.Dropout(0.3))
model_lstm.add(keras.layers.Dense(4, activation='softmax'))

optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_lstm.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 64)                11776
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 16,196
# Trainable params: 16,196
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm = model_lstm.fit(X_train, y_train, batch_size=16, epochs=100, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/100
# 45/45 [==============================] - 4s 28ms/step - loss: 1.5448 - accuracy: 0.2831 - val_loss: 1.4970 - val_accuracy: 0.3056
# Epoch 2/100
# 45/45 [==============================] - 0s 10ms/step - loss: 1.4585 - accuracy: 0.3138 - val_loss: 1.4345 - val_accuracy: 0.3111
100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2944 - accuracy: 0.9121 - val_loss: 0.5347 - val_accuracy: 0.8111
# Epoch 82/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2912 - accuracy: 0.9149 - val_loss: 0.5320 - val_accuracy: 0.8111
# Epoch 83/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2874 - accuracy: 0.9149 - val_loss: 0.5308 - val_accuracy: 0.8167
# Epoch 84/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2841 - accuracy: 0.9163 - val_loss: 0.5296 - val_accuracy: 0.8167
# Epoch 85/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2808 - accuracy: 0.9177 - val_loss: 0.5261 - val_accuracy: 0.8167
# Epoch 86/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2780 - accuracy: 0.9191 - val_loss: 0.5242 - val_accuracy: 0.8167
# Epoch 87/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2745 - accuracy: 0.9219 - val_loss: 0.5216 - val_accuracy: 0.8222
# Epoch 88/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2719 - accuracy: 0.9205 - val_loss: 0.5195 - val_accuracy: 0.8222
# Epoch 89/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2687 - accuracy: 0.9205 - val_loss: 0.5176 - val_accuracy: 0.8222
# Epoch 90/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2659 - accuracy: 0.9205 - val_loss: 0.5157 - val_accuracy: 0.8222
# Epoch 91/100
# 45/45 [==============================] - 0s 11ms/step - loss: 0.2625 - accuracy: 0.9205 - val_loss: 0.5153 - val_accuracy: 0.8222
# Epoch 92/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2592 - accuracy: 0.9247 - val_loss: 0.5135 - val_accuracy: 0.8222
# Epoch 93/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2564 - accuracy: 0.9261 - val_loss: 0.5130 - val_accuracy: 0.8222
# Epoch 94/100
# 45/45 [==============================] - 1s 11ms/step - loss: 0.2536 - accuracy: 0.9261 - val_loss: 0.5137 - val_accuracy: 0.8278
# Epoch 95/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2508 - accuracy: 0.9247 - val_loss: 0.5112 - val_accuracy: 0.8278
# Epoch 96/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2471 - accuracy: 0.9275 - val_loss: 0.5121 - val_accuracy: 0.8333
# Epoch 97/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2450 - accuracy: 0.9261 - val_loss: 0.5136 - val_accuracy: 0.8278
# Epoch 98/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2416 - accuracy: 0.9289 - val_loss: 0.5105 - val_accuracy: 0.8278
# Epoch 99/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2392 - accuracy: 0.9303 - val_loss: 0.5110 - val_accuracy: 0.8278
# Epoch 100/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2360 - accuracy: 0.9303 - val_loss: 0.5082 - val_accuracy: 0.8278

# %%
history_dict = history_lstm.history
loss_values = history_dict['loss']
acc_values = history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values = history_dict['val_accuracy']
epochs=range(1,101)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss_lstm, test_acc_lstm = model_lstm.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5967 - accuracy: 0.7867

# %%
def predict(model, X, y):

    X = X[np.newaxis, ...] 

    print (X.shape)
    prediction = model.predict(X)

    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


X_to_predict = X_test[100]
y_to_predict = y_test[100]

predict(model, X_to_predict, y_to_predict)
# Out:
# (1, 15, 13, 1)
# Target: 1, Predicted label: [2]

# %%
X_to_predict.shape
# Out:
# (15, 13, 1)

# %%
pred = model.predict(X_test)

# %%
pred2 = np.argmax(pred, axis=1)

# %%
y_test
# Out:
# array([2, 0, 0, 2, 0, 3, 2, 2, 0, 2, 2, 1, 0, 0, 3, 0, 3, 3, 0, 0, 0, 0,
#        1, 1, 0, 2, 0, 1, 2, 2, 0, 1, 2, 3, 3, 3, 3, 1, 0, 2, 0, 1, 3, 0,
#        1, 0, 0, 3, 2, 0, 1, 1, 3, 1, 3, 2, 2, 0, 1, 0, 2, 2, 2, 1, 3, 0,
#        1, 1, 2, 3, 0, 0, 1, 2, 3, 1, 2, 3, 2, 1, 2, 0, 1, 0, 0, 3, 1, 0,
#        3, 2, 1, 3, 1, 3, 2, 2, 2, 3, 1, 3, 1, 1, 3, 2, 3, 3, 0, 0, 3, 0,
#        1, 1, 0, 0, 2, 2, 0, 2, 2, 1, 0, 2, 2, 1, 1, 0, 0, 2, 1, 1, 3, 0,
#        3, 3, 1, 1, 0, 2, 3, 2, 1, 0, 0, 0, 0, 3, 3, 2, 3, 0, 0, 1, 3, 2,
#        2, 0, 3, 3, 2, 2, 1, 3, 1, 1, 3, 2, 3, 1, 0, 0, 2, 2, 0, 3, 3, 2,
#        1, 0, 0, 1, 1, 2, 1, 2, 1, 3, 0, 2, 3, 1, 3, 1, 3, 3, 3, 1, 1, 1,
#        2, 3, 1, 0, 2, 2, 0, 3, 2, 0, 2, 1, 1, 3, 1, 1, 2, 1, 2, 3, 1, 1,
#        1, 1, 2, 2, 3, 2, 1, 0, 1, 3, 0, 3, 0, 2, 3, 1, 2, 3, 2, 3, 3, 2,
#        3, 2, 3, 0, 1, 2, 0, 2, 0, 3, 1, 1, 0, 1, 2, 2, 1, 2, 0, 0, 1, 0,
#        0, 0, 1, 1, 3, 3, 3, 2, 0, 0, 0, 0, 3, 1, 1, 3, 3, 3, 3, 1, 1, 2,
#        2, 0, 3, 3, 1, 0, 2, 0, 1, 2, 1, 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, pred2)

# %%
Result = pd.DataFrame(conf_mat, 
                      index=['Angry', 'Happy', 'Nuetral', 'Sad'], 
                      columns=['Angry', 'Happy', 'Nuetral', 'Sad'])

# %%
Result
# Out:
#          Angry  Happy  Nuetral  Sad
# Angry       74      4        0    0
# Happy        8     57       11    2
# Nuetral      6     10       56    1
# Sad          0      4        4   63

# %%
data = {'ANN':20, '':15, 'Java':30,
        'Python':35}
courses = ['ANN', 'CNN']
values = [test_acc1, test_acc]
  
fig = plt.figure(figsize = (10, 5))
 
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy with Models")
plt.show()

# %%
model.save('voice_model.HDF5')
# Out:
# INFO:tensorflow:Assets written to: voice_model.HDF5\assets
