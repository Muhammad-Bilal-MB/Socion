# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings
import tensorflow as tf
import seaborn as sb
import librosa
import IPython.display as ipd
import librosa.display
import json
import math
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from keras import models, layers, optimizers
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Testing an audio file to check if it is working fine while loading

# %%
path = os.getcwd()
file = "Solely Urdu Dataset/Angry"
new = os.path.join(path, file)
os.chdir(new)

# %%
ipd.Audio(os.listdir()[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Plotting a waveplot of an audio to understand how amplitude varies with time

# %%
y, sr = librosa.load(os.listdir()[0], duration=3.00)
mfccs = librosa.feature.mfcc(y, sr=sr, n_mfcc=13)
delta_mfccs = librosa.feature.delta(mfccs)
delta_delta_mfccs = librosa.feature.delta(mfccs, order=2)
comprehensive_mfccs = np.concatenate((mfccs, delta_mfccs, delta_delta_mfccs))
print(comprehensive_mfccs.shape)
print(librosa.display.waveplot(comprehensive_mfccs, sr=sr))

# %%
ps = librosa.feature.melspectrogram(y=y, sr=sr)
print(librosa.display.waveplot(ps, sr=sr))

# %%
spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000) 
spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(spectrogram, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Angry')
plt.savefig('MelSpec_MaleNeutral.png')
plt.colorbar(format='%+2.0f dB');

# %% [markdown]
# ### Creating Mel Frequency Cepstral Coefficients dataset for each voice sample in a JSON file

# %%
DATASET_PATH = "D:/Solely Urdu Dataset/"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 1
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=3):
    """Extracts MFCCs from Urdu voice dataset and saves them into a json file along witgh emotion labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save MFCCs
        :param num_mfcc (int): Number of coefficients to extract
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :return:
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all voice sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a voice sub-folder level
        if dirpath is not dataset_path:

            # save voice label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in voice sub-dir
            for f in filenames:

            # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(signal[start:finish],
                                                sample_rate, 
                                                n_mfcc=num_mfcc, 
                                                n_fft=n_fft, 
                                                hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))


    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        

save_mfcc(DATASET_PATH, JSON_PATH, num_segments=3)

# %% [markdown]
# ### Loading Data

# %%
DATA_PATH = "D:/Urdu_Voice/data.json"

def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    x = np.array(data["mfcc"])
    y = np.array(data["labels"])
    
    print("Data succesfully loaded!")

    return  x, y

x, y = load_data(DATA_PATH)
# Out:
# Data succesfully loaded!

# %%
len(x[0][0])
# Out:
# 13

# %%
x.shape, y.shape
# Out:
# ((1197, 15, 13), (1197,))

# %% [markdown]
# ### Artificial Neural Networtk (ANN) model building

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(x.shape[1], x.shape[2])),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(4, activation='softmax')
])

optimiser = keras.optimizers.Adam()
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 195)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               100352
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 248,388
# Trainable params: 248,388
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=16, epochs=100, validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/100
# 45/45 [==============================] - 1s 7ms/step - loss: 7.9938 - accuracy: 0.5635 - val_loss: 2.1969 - val_accuracy: 0.7333
# Epoch 2/100
# 45/45 [==============================] - 0s 4ms/step - loss: 2.2227 - accuracy: 0.7099 - val_loss: 3.6840 - val_accuracy: 0.6944
# Epoch 3/100
# 45/45 [==============================] - 0s 4ms/step - loss: 2.1743 - accuracy: 0.7043 - val_loss: 1.2367 - val_accuracy: 0.7500
# Epoch 4/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.9880 - accuracy: 0.7880 - val_loss: 0.9127 - val_accuracy: 0.7611
# Epoch 5/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.6511 - accuracy: 0.8298 - val_loss: 1.1563 - val_accuracy: 0.7556
# Epoch 6/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4632 - accuracy: 0.8703 - val_loss: 0.8226 - val_accuracy: 0.8278
# Epoch 7/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.4702 - accuracy: 0.8675 - val_loss: 1.1839 - val_accuracy: 0.7944
# Epoch 8/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2961 - accuracy: 0.9024 - val_loss: 1.0043 - val_accuracy: 0.7833
# Epoch 9/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2717 - accuracy: 0.9191 - val_loss: 1.2723 - val_accuracy: 0.8111
# Epoch 10/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.2291 - accuracy: 0.9344 - val_loss: 0.7469 - val_accuracy: 0.8333
# Epoch 11/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1255 - accuracy: 0.9665 - val_loss: 0.6858 - val_accuracy: 0.8444
# Epoch 12/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1154 - accuracy: 0.9526 - val_loss: 0.9399 - val_accuracy: 0.8278
# Epoch 13/100
# 45/45 [==============================] - 0s 4ms/step - loss: 0.
# 45/45 [==============================] - 0s 4ms/step - loss: 4.2638e-05 - accuracy: 1.0000 - val_loss: 0.9214 - val_accuracy: 0.9056
# Epoch 100/100
# 45/45 [==============================] - 0s 4ms/step - loss: 4.1723e-05 - accuracy: 1.0000 - val_loss: 0.9210 - val_accuracy: 0.9056

# %%
history_dict=history.history
loss_values=history_dict['loss']
acc_values=history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values=history_dict['val_accuracy']
epochs=range(1,101)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss1, test_acc1 = model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9828 - accuracy: 0.8533

# %% [markdown]
# ### Splitting data into validation, training, test

# %%
def prepare_datasets(test_size, validation_size):
    
    X, y = load_data(DATA_PATH)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)
    #X_train = X_train[..., np.newaxis]
    #X_validation = X_validation[..., np.newaxis]
    #X_test = X_test[..., np.newaxis]
    
    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)
# Out:
# Data succesfully loaded!

# %% [markdown]
# ### Changing Data Shape and Adding new axis for Conv2D

# %%
X_train_Conv2D = X_train[..., np.newaxis]
X_validation_Conv2D = X_validation[..., np.newaxis]
X_test_Conv2D = X_test[..., np.newaxis]

# %%
X_train_Conv2D.shape
# Out:
# (717, 15, 13, 1)

# %%
X_train.shape
# Out:
# (717, 15, 13)

# %% [markdown]
# ### Convolutional 2D Neural Network Model

# %%
model = keras.Sequential()

model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(X_train_Conv2D.shape[1], X_train_Conv2D.shape[2], 1)))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))

model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))

model.add(keras.layers.Flatten())

#model.add(keras.layers.LSTM(200, activation='relu', return_sequences=True))

model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(4, activation='softmax'))

optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# %%
history2 = model.fit(X_train_Conv2D, y_train, batch_size=16, epochs=100, validation_data=(X_validation_Conv2D, y_validation))
# Out:
# Epoch 1/100
# 45/45 [==============================] - 1s 12ms/step - loss: 1.5175 - accuracy: 0.3473 - val_loss: 1.5270 - val_accuracy: 0.3111
# Epoch 2/100
# 45/45 [==============================] - 0s 8ms/step - loss: 1.2991 - accuracy: 0.4045 - val_loss: 1.2387 - val_accuracy: 0.3778
# Epoch 3/100
# 45/45 [==============================] - 0s 8ms/step - loss: 1.2021 - accuracy: 0.4798 - val_loss: 1.0911 - val_accuracy: 0.6000
# Epoch 4/100
# 45/45 [==============================] - 0s 8ms/step - loss: 1.1160 - accuracy: 0.5300 - val_loss: 1.0008 - val_accuracy: 0.6556
# Epoch 5/100
# 45/45 [==============================] - 0s 8ms/step - loss: 1.0411 - accuracy: 0.5844 - val_loss: 0.9318 - val_accuracy: 0.6667
# Epoch 6/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.9859 - accuracy: 0.5955 - val_loss: 0.8825 - val_accuracy: 0.6833
# Epoch 7/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.9346 - accuracy: 0.6332 - val_loss: 0.8608 - val_accuracy: 0.7000
# Epoch 8/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.9444 - accuracy: 0.6430 - val_loss: 0.8352 - val_accuracy: 0.7056
# Epoch 9/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.8525 - accuracy: 0.6778 - val_loss: 0.8211 - val_accuracy: 0.7056
# Epoch 10/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.8742 - accuracy: 0.6639 - val_loss: 0.8217 - val_accuracy: 0.6944
# Epoch 11/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.8052 - accuracy: 0.6960 - val_loss: 0.7875 - val_accuracy: 0.7167
# Epoch 12/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.8012 - accuracy: 0.7057 - val_loss: 0.7683 - val_accuracy: 0.7111
# Epoch 13/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.7626 - accuracy: 0.7155 - val_loss: 0.7559 - val_accuracy: 0.7056
# Epoch 14/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.7543 - accuracy: 0.7350 - val_loss: 0.7334 - val_accuracy: 0.7111
# Epoch 15/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.7442 - accuracy: 0.7336 - val_loss: 0.7336 - val_accuracy: 0.7333
# Epoch 16/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.7270 - accuracy: 0.7420 - val_loss: 0.7184 - val_accuracy: 0.7278
# Epoch 17/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6788 - accuracy: 0.7448 - val_loss: 0.7155 - val_accuracy: 0.7500
# Epoch 18/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.6866 - accuracy: 0.7476 - val_loss: 0.7061 - val_accuracy: 0.7500
# Epoch 19/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6392 - accuracy: 0.7727 - val_loss: 0.6985 - val_accuracy: 0.7556
# Epoch 20/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6301 - accuracy: 0.7741 - val_loss: 0.6892 - val_accuracy: 0.7611
# Epoch 21/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6146 - accuracy: 0.7936 - val_loss: 0.6879 - val_accuracy: 0.7500
# Epoch 22/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6024 - accuracy: 0.7852 - val_loss: 0.6696 - val_accuracy: 0.7667
# Epoch 23/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.6180 - accuracy: 0.7727 - val_loss: 0.6685 - val_accuracy: 0.7611
# Epoch 24/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.5673 - accuracy: 0.7852 - val_loss: 0.6571 - val_accuracy: 0.7667
# Epoch 25/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.5906 - accuracy: 0.7810 - val_loss: 0.6591 - val_accuracy: 0.7611
# Epoch 26/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.5719 - accuracy: 0.7950 - val_loss: 0.6323 - val_accuracy: 0.7611
# Epoch 27/100
# 45/45 [==============================] - 0s 9ms/step - loss: 0.5402 - accuracy: 0.8103 - val_loss: 0.6320 - val_accuracy: 0.7667
# Epoch 28/100
# 45/45 [==============================] - 0s 10ms/step - loss: 0.4996 - accuracy: 0.8257 - val_loss: 0.6353 - val_accuracy: 0.7667
# Epoch 29/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0
100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1860 - accuracy: 0.9526 - val_loss: 0.5908 - val_accuracy: 0.7944
# Epoch 91/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1672 - accuracy: 0.9568 - val_loss: 0.6050 - val_accuracy: 0.7944
# Epoch 92/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1711 - accuracy: 0.9456 - val_loss: 0.5688 - val_accuracy: 0.8000
# Epoch 93/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1540 - accuracy: 0.9568 - val_loss: 0.5738 - val_accuracy: 0.8167
# Epoch 94/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1767 - accuracy: 0.9456 - val_loss: 0.6179 - val_accuracy: 0.7944
# Epoch 95/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1804 - accuracy: 0.9456 - val_loss: 0.6323 - val_accuracy: 0.7889
# Epoch 96/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.2093 - accuracy: 0.9400 - val_loss: 0.6112 - val_accuracy: 0.8000
# Epoch 97/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1468 - accuracy: 0.9540 - val_loss: 0.6047 - val_accuracy: 0.7944
# Epoch 98/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1422 - accuracy: 0.9637 - val_loss: 0.5646 - val_accuracy: 0.8167
# Epoch 99/100
# 45/45 [==============================] - 0s 7ms/step - loss: 0.1572 - accuracy: 0.9470 - val_loss: 0.5538 - val_accuracy: 0.8056
# Epoch 100/100
# 45/45 [==============================] - 0s 8ms/step - loss: 0.1943 - accuracy: 0.9414 - val_loss: 0.5795 - val_accuracy: 0.8000

# %%
history_dict = history2.history
loss_values = history_dict['loss']
acc_values = history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values = history_dict['val_accuracy']
epochs=range(1,101)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss_Conv2D, test_acc_Conv2D = model.evaluate(X_test_Conv2D, y_test)
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5199 - accuracy: 0.8200

# %% [markdown]
# ### Convolutional 1D Model

# %%
model_conv1D = keras.Sequential()

model_conv1D.add(keras.layers.Conv1D(32, 3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model_conv1D.add(keras.layers.MaxPool1D(3, strides=2, padding='same'))

model_conv1D.add(keras.layers.Conv1D(32, 3, activation='relu'))
model_conv1D.add(keras.layers.MaxPool1D(3, strides=2, padding='same'))

model_conv1D.add(keras.layers.Conv1D(32, 3, activation='relu'))
model_conv1D.add(keras.layers.MaxPool1D(2, strides=2, padding='same'))

model_conv1D.add(keras.layers.Flatten())
model_conv1D.add(keras.layers.Dense(64, activation='relu'))
model_conv1D.add(keras.layers.Dropout(0.3))
model_conv1D.add(keras.layers.Dense(4, activation='softmax'))

optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_conv1D.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model_conv1D.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_26 (Conv1D)           (None, 13, 32)            1280
# _________________________________________________________________
# max_pooling1d_24 (MaxPooling (None, 7, 32)             0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 5, 32)             3104
# _________________________________________________________________
# max_pooling1d_25 (MaxPooling (None, 3, 32)             0
# _________________________________________________________________
# conv1d_28 (Conv1D)           (None, 1, 32)             3104
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 1, 32)             0
# _________________________________________________________________
# flatten_8 (Flatten)          (None,
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9665 - val_loss: 0.5872 - val_accuracy: 0.8333
# Epoch 159/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0904 - accuracy: 0.9637 - val_loss: 0.6092 - val_accuracy: 0.8222
# Epoch 160/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9665 - val_loss: 0.5975 - val_accuracy: 0.8278
# Epoch 161/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0826 - accuracy: 0.9735 - val_loss: 0.6265 - val_accuracy: 0.8167
# Epoch 162/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9735 - val_loss: 0.6238 - val_accuracy: 0.8278
# Epoch 163/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9596 - val_loss: 0.6172 - val_accuracy: 0.8056
# Epoch 164/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9623 - val_loss: 0.6054 - val_accuracy: 0.8111
# Epoch 165/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0899 - accuracy: 0.9749 - val_loss: 0.7112 - val_accuracy: 0.8111
# Epoch 166/300
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0881 - accuracy: 0.9749 - val_loss: 0.6470 - val_accuracy: 0.8444
# Epoch 167/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9791 - val_loss: 0.6332 - val_accuracy: 0.8278
# Epoch 168/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0856 - accuracy: 0.9707 - val_loss: 0.6193 - val_accuracy: 0.8444
# Epoch 169/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0887 - accuracy: 0.9707 - val_loss: 0.7062 - val_accuracy: 0.8056
# Epoch 170/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.9749 - val_loss: 0.6398 - val_accuracy: 0.8333
# Epoch 171/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9777 - val_loss: 0.6364 - val_accuracy: 0.8278
# Epoch 172/300
# 45/45 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9777 - val_loss: 0.6149 - val_accuracy: 0.8333
# Epoch 173/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0750 - accuracy: 0.9819 - val_loss: 0.6962 - val_accuracy: 0.8000
# Epoch 174/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0741 - accuracy: 0.9819 - val_loss: 0.6545 - val_accuracy: 0.8389
# Epoch 175/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0727 - accuracy: 0.9777 - val_loss: 0.6772 - val_accuracy: 0.8222
# Epoch 176/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0698 - accuracy: 0.9777 - val_loss: 0.6734 - val_accuracy: 0.8333
# Epoch 177/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9805 - val_loss: 0.6788 - val_accuracy: 0.8389
# Epoch 178/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9749 - val_loss: 0.6678 - val_accuracy: 0.8278
# Epoch 179/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0633 - accuracy: 0.9819 - val_loss: 0.6727 - val_accuracy: 0.8333
# Epoch 180/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0675 - accuracy: 0.9805 - val_loss: 0.7142 - val_accuracy: 0.8111
# Epoch 181/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9763 - val_loss: 0.6745 - val_accuracy: 0.8333
# Epoch 182/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9833 - val_loss: 0.7033 - val_accuracy: 0.8278
# Epoch 183/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0751 - accuracy: 0.9791 - val_loss: 0.6728 - val_accuracy: 0.8444
# Epoch 184/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9833 - val_loss: 0.6872 - val_accuracy: 0.8278
# Epoch 185/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9833 - val_loss: 0.6870 - val_accuracy: 0.8333
# Epoch 186/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9777 - val_loss: 0.7397 - val_accuracy: 0.8222
# Epoch 187/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9874 - val_loss: 0.6776 - val_accuracy: 0.8278
# Epoch 188/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.
300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9972 - val_loss: 0.8491 - val_accuracy: 0.8500
# Epoch 251/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9986 - val_loss: 0.9053 - val_accuracy: 0.8500
# Epoch 252/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0234 - accuracy: 0.9944 - val_loss: 0.8630 - val_accuracy: 0.8444
# Epoch 253/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9958 - val_loss: 0.8674 - val_accuracy: 0.8278
# Epoch 254/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9930 - val_loss: 0.8338 - val_accuracy: 0.8333
# Epoch 255/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9972 - val_loss: 0.8964 - val_accuracy: 0.8167
# Epoch 256/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9958 - val_loss: 0.9092 - val_accuracy: 0.8111
# Epoch 257/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9986 - val_loss: 0.8895 - val_accuracy: 0.8278
# Epoch 258/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 0.9958 - val_loss: 0.8695 - val_accuracy: 0.8333
# Epoch 259/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9958 - val_loss: 0.8178 - val_accuracy: 0.8556
# Epoch 260/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 0.9874 - val_loss: 0.8928 - val_accuracy: 0.8222
# Epoch 261/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9805 - val_loss: 0.8944 - val_accuracy: 0.8444
# Epoch 262/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 1.0031 - val_accuracy: 0.7944
# Epoch 263/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.9944 - val_loss: 0.9740 - val_accuracy: 0.8167
# Epoch 264/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 0.9958 - val_loss: 0.9145 - val_accuracy: 0.8389
# Epoch 265/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9930 - val_loss: 0.8443 - val_accuracy: 0.8333
# Epoch 266/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9930 - val_loss: 0.8657 - val_accuracy: 0.8333
# Epoch 267/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9972 - val_loss: 0.8740 - val_accuracy: 0.8333
# Epoch 268/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9930 - val_loss: 1.0456 - val_accuracy: 0.8056
# Epoch 269/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9972 - val_loss: 0.9188 - val_accuracy: 0.8389
# Epoch 270/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0233 - accuracy: 0.9958 - val_loss: 0.9499 - val_accuracy: 0.8444
# Epoch 271/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.9178 - val_accuracy: 0.8278
# Epoch 272/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9972 - val_loss: 0.9304 - val_accuracy: 0.8444
# Epoch 273/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9986 - val_loss: 0.9128 - val_accuracy: 0.8389
# Epoch 274/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.9469 - val_accuracy: 0.8167
# Epoch 275/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9944 - val_loss: 0.9420 - val_accuracy: 0.8278
# Epoch 276/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9972 - val_loss: 0.9659 - val_accuracy: 0.8389
# Epoch 277/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9930 - val_loss: 0.9089 - val_accuracy: 0.8222
# Epoch 278/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.9751 - val_accuracy: 0.8278
# Epoch 279/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.0032 - val_accuracy: 0.8222
# Epoch 280/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9986 - val_loss: 0.9347 - val_accuracy: 0.8389
# Epoch 281/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9986 - val_loss: 0.9845 - val_accuracy: 0.8278
# Epoch 282/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.9342 - val_accuracy: 0.8556
# Epoch 283/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.9314 - val_accuracy: 0.8389
# Epoch 284/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.9860 - val_accuracy: 0.8167
# Epoch 285/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9958 - val_loss: 0.9197 - val_accuracy: 0.8389
# Epoch 286/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9888 - val_loss: 0.9667 - val_accuracy: 0.8167
# Epoch 287/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9930 - val_loss: 0.9299 - val_accuracy: 0.8278
# Epoch 288/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9986 - val_loss: 0.9551 - val_accuracy: 0.8333
# Epoch 289/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0218 - accuracy: 0.9958 - val_loss: 1.0144 - val_accuracy: 0.8167
# Epoch 290/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.9277 - val_accuracy: 0.8278
# Epoch 291/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.9849 - val_accuracy: 0.8222
# Epoch 292/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 0.9972 - val_loss: 1.0947 - val_accuracy: 0.8333
# Epoch 293/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 1.0064 - val_accuracy: 0.8111
# Epoch 294/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9986 - val_loss: 0.9520 - val_accuracy: 0.8389
# Epoch 295/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 0.9184 - val_accuracy: 0.8444
# Epoch 296/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.9850 - val_accuracy: 0.8500
# Epoch 297/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.9848 - val_accuracy: 0.8389
# Epoch 298/300
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9986 - val_loss: 0.9486 - val_accuracy: 0.8389
# Epoch 299/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9944 - val_loss: 0.9365 - val_accuracy: 0.8222
# Epoch 300/300
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 0.9888 - val_loss: 0.8347 - val_accuracy: 0.8333

# %%
history_dict = history3.history
loss_values = history_dict['loss']
acc_values = history_dict['accuracy']
val_loss_values = history_dict['val_loss']
val_acc_values = history_dict['val_accuracy']
epochs=range(1,301)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(15,5))
ax1.plot(epochs,loss_values,'bo',label='Training Loss')
ax1.plot(epochs,val_loss_values,'orange', label='Validation Loss')
ax1.set_title('Training and validation loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()
ax2.plot(epochs,acc_values,'bo', label='Training accuracy')
ax2.plot(epochs,val_acc_values,'orange',label='Validation accuracy')
ax2.set_title('Training and validation accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()
plt.show()

# %%
test_loss_conv1D, test_acc_conv1D = model_conv1D.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1039 - accuracy: 0.8033

# %%
def predict(model, X, y):

    X = X[np.newaxis, ...] 

    print (X.shape)
    prediction = model.predict(X)

    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


X_to_predict = X_test[100]
y_to_predict = y_test[100]

predict(model, X_to_predict, y_to_predict)
# Out:
# (1, 15, 13, 1)
# Target: 1, Predicted label: [2]

# %%
X_to_predict.shape
# Out:
# (15, 13, 1)

# %%
pred = model.predict(X_test)

# %%
pred2 = np.argmax(pred, axis=1)

# %%
y_test
# Out:
# array([2, 0, 0, 2, 0, 3, 2, 2, 0, 2, 2, 1, 0, 0, 3, 0, 3, 3, 0, 0, 0, 0,
#        1, 1, 0, 2, 0, 1, 2, 2, 0, 1, 2, 3, 3, 3, 3, 1, 0, 2, 0, 1, 3, 0,
#        1, 0, 0, 3, 2, 0, 1, 1, 3, 1, 3, 2, 2, 0, 1, 0, 2, 2, 2, 1, 3, 0,
#        1, 1, 2, 3, 0, 0, 1, 2, 3, 1, 2, 3, 2, 1, 2, 0, 1, 0, 0, 3, 1, 0,
#        3, 2, 1, 3, 1, 3, 2, 2, 2, 3, 1, 3, 1, 1, 3, 2, 3, 3, 0, 0, 3, 0,
#        1, 1, 0, 0, 2, 2, 0, 2, 2, 1, 0, 2, 2, 1, 1, 0, 0, 2, 1, 1, 3, 0,
#        3, 3, 1, 1, 0, 2, 3, 2, 1, 0, 0, 0, 0, 3, 3, 2, 3, 0, 0, 1, 3, 2,
#        2, 0, 3, 3, 2, 2, 1, 3, 1, 1, 3, 2, 3, 1, 0, 0, 2, 2, 0, 3, 3, 2,
#        1, 0, 0, 1, 1, 2, 1, 2, 1, 3, 0, 2, 3, 1, 3, 1, 3, 3, 3, 1, 1, 1,
#        2, 3, 1, 0, 2, 2, 0, 3, 2, 0, 2, 1, 1, 3, 1, 1, 2, 1, 2, 3, 1, 1,
#        1, 1, 2, 2, 3, 2, 1, 0, 1, 3, 0, 3, 0, 2, 3, 1, 2, 3, 2, 3, 3, 2,
#        3, 2, 3, 0, 1, 2, 0, 2, 0, 3, 1, 1, 0, 1, 2, 2, 1, 2, 0, 0, 1, 0,
#        0, 0, 1, 1, 3, 3, 3, 2, 0, 0, 0, 0, 3, 1, 1, 3, 3, 3, 3, 1, 1, 2,
#        2, 0, 3, 3, 1, 0, 2, 0, 1, 2, 1, 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, pred2)

# %%
Result = pd.DataFrame(conf_mat, 
                      index=['Angry', 'Happy', 'Nuetral', 'Sad'], 
                      columns=['Angry', 'Happy', 'Nuetral', 'Sad'])

# %%
Result
# Out:
#          Angry  Happy  Nuetral  Sad
# Angry       74      4        0    0
# Happy        8     57       11    2
# Nuetral      6     10       56    1
# Sad          0      4        4   63

# %%
data = {'ANN':20, '':15, 'Java':30,
        'Python':35}
courses = ['ANN', 'CNN']
values = [test_acc1, test_acc]
  
fig = plt.figure(figsize = (10, 5))
 
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy with Models")
plt.show()

# %%
model.save('voice_model.HDF5')
# Out:
# INFO:tensorflow:Assets written to: voice_model.HDF5\assets
